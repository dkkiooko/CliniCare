# %%
import pandas as pd
df1 = pd.read_csv('https://query.data.world/s/hchnr6jcv2py6xrmekxm4gcz436be2')

# %%
df1.head(10)
# Out:
#   Provider First Name Provider Last Name                 Practice Name  \
# 0             Domingo            Santana   Bethel Medical Practice,P.C
# 1               Tarek             Hegazi              Better Care Inc.
# 2               Magdy           Mohammed              Better Care Inc.
# 3             Beverly               Hurd        Beverly W. Hurd, MD PC
# 4             Bhavana               Japi  Bhavana R. Japi Physician PC
# 5          Altagracia            Navarro      Bienvenido Fajardo MD PC
# 6          Bienvenido            Fajardo      Bienvenido Fajardo MD PC
# 7               Billy              Geris                Billy Geris MD
# 8         Jean Pierre            Barakat                Billy Geris MD
# 9             PCP FTE             Credit                Billy Geris MD
#
#   Primary Speciality                          Site Name Practice Borough  \
# 0  Internal Medicine        Bethel Medical Practice,P.C            Bronx
# ...

# %%
df1.shape
# Out:
# (2031, 10)

# %%
allergies = pd.read_csv('allergies.csv')

# %%
allergies.head()
# Out:
#      START STOP                               PATIENT  \
# 0  3/11/95  NaN  ab6d8296-d3c7-4fef-9215-40b156db67ac
# 1  3/11/95  NaN  ab6d8296-d3c7-4fef-9215-40b156db67ac
# 2  3/11/95  NaN  ab6d8296-d3c7-4fef-9215-40b156db67ac
# 3  3/11/95  NaN  ab6d8296-d3c7-4fef-9215-40b156db67ac
# 4  3/11/95  NaN  ab6d8296-d3c7-4fef-9215-40b156db67ac
#
#                               ENCOUNTER       CODE               DESCRIPTION
# 0  9d87c22d-a777-426b-b020-cfa469229f82  425525006  Allergy to dairy product
# 1  9d87c22d-a777-426b-b020-cfa469229f82  419263009    Allergy to tree pollen
# 2  9d87c22d-a777-426b-b020-cfa469229f82  418689008   Allergy to grass pollen
# 3  9d87c22d-a777-426b-b020-cfa469229f82  232347008   Dander (animal) allergy
# 4  9d87c22d-a777-426b-b020-cfa469229f82  232350006   House dust mite allergy

# %%
allergies.shape
# Out:
# (572, 6)

# %%
allergies.head(100)
# Out:
#       START     STOP                               PATIENT  \
# 0   3/11/95      NaN  ab6d8296-d3c7-4fef-9215-40b156db67ac
# 1   3/11/95      NaN  ab6d8296-d3c7-4fef-9215-40b156db67ac
# 2   3/11/95      NaN  ab6d8296-d3c7-4fef-9215-40b156db67ac
# 3   3/11/95      NaN  ab6d8296-d3c7-4fef-9215-40b156db67ac
# 4   3/11/95      NaN  ab6d8296-d3c7-4fef-9215-40b156db67ac
# ..      ...      ...                                   ...
# 95  1/18/94  3/17/10  f436e3f6-b2ef-4352-aef9-1b1563412b77
# 96  1/18/94  3/17/10  f436e3f6-b2ef-4352-aef9-1b1563412b77
# 97  1/18/94      NaN  f436e3f6-b2ef-4352-aef9-1b1563412b77
# 98  1/18/94  3/17/10  f436e3f6-b2ef-4352-aef9-1b1563412b77
# 99  6/29/16      NaN  c7c72b89-0345-43c7-bd8b-1800e2adae66
#
#                                ENCOUNTER       CODE               DESCRIPTION
# 0   9d87c22d-a777-426b-b020-cfa469229f82  425525006  Allergy to dairy product
# 1   9d87c22d-a777-426b-b020-cfa469229f82  419263009    Allergy to tree pollen
# ...
